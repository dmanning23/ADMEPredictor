# %% [markdown]
# # 02 – Featurization
#
# Demonstrate atom/bond feature extraction and graph construction for a few example molecules.

# %%
import sys
sys.path.insert(0, '../backend')

from featurization import smiles_to_graph, compute_descriptors, validate_smiles

ASPIRIN = 'CC(=O)OC1=CC=CC=C1C(=O)O'
print('Valid:', validate_smiles(ASPIRIN))

graph = smiles_to_graph(ASPIRIN)
print('Nodes:', graph.x.shape)
print('Edges:', graph.edge_index.shape)

# %%
desc = compute_descriptors(ASPIRIN)
print(f'Descriptor vector length: {len(desc)}')
